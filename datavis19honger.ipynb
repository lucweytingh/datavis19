# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

data = pd.read_csv("prevalence-of-undernourishment.csv")

# %%
data['Year'].max()
# Out:
# 2015

# %%
data.head()
# Out:
#         Entity Code  Year  \
# 0  Afghanistan  AFG  1991
# 1  Afghanistan  AFG  1992
# 2  Afghanistan  AFG  1993
# 3  Afghanistan  AFG  1994
# 4  Afghanistan  AFG  1995
#
#    Prevalence of undernourishment (% of population) (% of population)
# 0                                               29.5
# 1                                               35.6
# 2                                               39.2
# 3                                               43.3
# 4                                               45.4

# %%
data.columns
# Out:
# Index(['Entity', 'Code', 'Year',
#        'Prevalence of undernourishment (% of population) (% of population)'],
#       dtype='object')

# %%
data['Entity']
# Out:
# 0       Afghanistan
# 1       Afghanistan
# 2       Afghanistan
# 3       Afghanistan
# 4       Afghanistan
# 5       Afghanistan
# 6       Afghanistan
# 7       Afghanistan
# 8       Afghanistan
# 9       Afghanistan
# 10      Afghanistan
# 11      Afghanistan
# 12      Afghanistan
# 13      Afghanistan
# 14      Afghanistan
# 15      Afghanistan
# 16      Afghanistan
# 17      Afghanistan
# 18      Afghanistan
# 19      Afghanistan
# 20      Afghanistan
# 21      Afghanistan
# 22      Afghanistan
# 23      Afghanistan
# 24      Afghanistan
# 25          Algeria
# 26          Algeria
# 27          Algeria
# 28          Algeria
# 29          Algeria
#            ...
# 3709         Zambia
# 3710         Zambia
# 3711         Zambia
# 3712         Zambia
# 3713         Zambia
# 3714       Zimbabwe
# 3715       Zimbabwe
# 3716       Zimbabwe
# 3717       Zimbabwe
# 3718       Zimbabwe
# 3719       Zimbabwe
# 3720       Zimbabwe
# 3721       Zimbabwe
# 3722       Zimbabwe
# ...

# %%
df3 = pd.DataFrame(np.random.randn(1000, 2))

# %%
df3['Year'] = pd.Series(list(range(len(data))))

# %%
data.groupby('Entity').plot(x='Year',y='Prevalence of undernourishment (% of population) (% of population)')
# Out:
# /home/andreas/anaconda3/lib/python3.6/site-packages/matplotlib/pyplot.py:537: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
# Entity
# Afghanistan                                   AxesSubplot(0.125,0.125;0.775x0.755)
# Algeria                                       AxesSubplot(0.125,0.125;0.775x0.755)
# Angola                                        AxesSubplot(0.125,0.125;0.775x0.755)
# Arab World                                    AxesSubplot(0.125,0.125;0.775x0.755)
# Argentina                                     AxesSubplot(0.125,0.125;0.775x0.755)
# Armenia                                       AxesSubplot(0.125,0.125;0.775x0.755)
# Azerbaijan                                    AxesSubplot(0.125,0.125;0.775x0.755)
# ...

# %%
fig, ax = plt.subplots()
data.groupby('Entity').plot(x='Year',y='Prevalence of undernourishment (% of population) (% of population)',ax=ax, legend=False)
fig.savefig("hunger.png")

# %%
data.groupby("Entity")["Prevalence of undernourishment (% of population) (% of population)"].mean()
# Out:
# Entity
# Afghanistan                                   35.812000
# Algeria                                        6.984000
# Angola                                        40.592000
# Arab World                                     9.582924
# Argentina                                      5.000000
# Armenia                                       15.296000
# Azerbaijan                                    14.144000
# Bangladesh                                    23.508000
# Barbados                                       5.324000
# Belize                                         6.252000
# Benin                                         18.968000
# Bolivia                                       29.980000
# Botswana                                      30.632000
# Brazil                                         9.048000
# Brunei                                         5.000000
# Burkina Faso                                  23.848000
# Cambodia                                      24.320000
# ...

# %%
data.groupby("Entity")["Prevalence of undernourishment (% of population) (% of population)"].var()
# Out:
# Entity
# Afghanistan                                    74.862767
# Algeria                                         2.043067
# Angola                                        333.887433
# Arab World                                      0.333726
# Argentina                                       0.000000
# Armenia                                        67.144567
# Azerbaijan                                     95.254233
# Bangladesh                                     64.080767
# Barbados                                        0.356067
# Belize                                          1.290933
# Benin                                          51.920600
# Bolivia                                        40.391667
# Botswana                                       12.906433
# Brazil                                         17.184267
# Brunei                                          0.000000
# Burkina Faso                                    6.001767
# ...
